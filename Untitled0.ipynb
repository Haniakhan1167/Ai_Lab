# %%
set_a = {1,2,3,4}
set_b = {5,6,7,8}
print('union :', set_a | set_b)
# Out:
# union : {1, 2, 3, 4, 5, 6, 7, 8}

# %%
set_a = {1,2,3,4,6}
set_b = {5,6,4,3}
print('intersection :', set_a | set_b)
# Out:
# intersection : {1, 2, 3, 4, 5, 6}

# %%
students = {'Ali' : 85, 'Hania' : 100, 'Nida' : 100}
